# %% [markdown]
# SAT SCORE PREDICTOR
# ama908

# %%
#Importing Packages
import pandas as pd
import os
import csv
import pylab as pl
from pandas.tools.plotting import scatter_matrix
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# SAT SCORE CSV FILE
sat_score = pd.read_csv('SAT_Results.csv')
print sat_score.columns
# Out:
# Index([u'DBN', u'SCHOOL NAME', u'Num of SAT Test Takers',
#        u'SAT Critical Reading Avg. Score', u'SAT Math Avg. Score',
#        u'SAT Writing Avg. Score', u'District', u'SAT Total TOTAL',
#        u'Unnamed: 8', u'Unnamed: 9', u'Unnamed: 10', u'Unnamed: 11'],
#       dtype='object')

# %%
# SORTING SAT SCORE 
Output_SAT = sat_score.groupby('District').mean()

# %%
Output_SAT.head()
# Out:
#           Num of SAT Test Takers  SAT Critical Reading Avg. Score  \
# District
# 1                      73.333333                       423.777778
# 2                     106.465517                       424.068966
# 3                     108.769231                       424.846154
# 4                      99.428571                       393.142857
# 5                      70.444444                       407.333333
#
#           SAT Math Avg. Score  SAT Writing Avg. Score  SAT Total TOTAL  \
# District
# 1                  468.444444              413.555556      1305.777778
# 2                  441.344828              419.448276      1284.862069
# 3                  426.000000              417.076923      1267.923077
# 4                  405.285714              392.714286      1191.142857
# 5                  409.666667              401.222222      1218.222222
#
#           Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# District
# 1                NaN         NaN          NaN          NaN
# 2                NaN         NaN          NaN          NaN
# 3                NaN         NaN          NaN          NaN
# 4                NaN         NaN          NaN          NaN
# 5                NaN         NaN          NaN          NaN

# %%
attendance = pd.read_csv('School_Attendance_And_Enrollment_By_District_-_2010-11.csv')

# %%
attendance.head()
# Out:
#           Dist  YTD % Attendance (Avg)  YTD Enrollment (Avg)  District
# 0  DISTRICT 01                   91.18                 12367         1
# 1  DISTRICT 02                   89.01                 60823         2
# 2  DISTRICT 03                   89.20                 21962         3
# 3  DISTRICT 04                   91.13                 14252         4
# 4  DISTRICT 05                   89.08                 13170         5

# %%
X = attendance['YTD % Attendance (Avg)'][0:32]
Y = Output_SAT['SAT Total TOTAL'][0:32]

# %%
X.index = Y.index

# %%
Z = sm.add_constant(X)
model = sm.OLS(Y, Z, drop='missing') # ignores entires where x or y is NaN
fit = model.fit()
print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        SAT Total TOTAL   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.502
# Method:                 Least Squares   F-statistic:                     32.22
# Date:                Fri, 11 Dec 2015   Prob (F-statistic):           3.45e-06
# Time:                        01:47:02   Log-Likelihood:                -177.37
# No. Observations:                  32   AIC:                             358.7
# Df Residuals:                      30   BIC:                             361.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# const                  -1750.9744    521.446     -3.358      0.002     -2815.910  -686.039
# YTD % Attendance (Avg)    32.8776      5.792      5.677      0.000        21.049    44.706
# ==============================================================================
# Omnibus:                        2.476   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.290   Jarque-Bera (JB):                1.339
# Skew:                           0.134   Prob(JB):                        0.512
# Kurtosis:                       2.034   Cond. No.                     4.16e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.16e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pl.figure(figsize=(5, 5))
pl.scatter(X, Y)
plot(X, fit.predict(), 'k')
pl.ylabel('Average SAT Score')
pl.xlabel('Average School Attendance')

# %%
attend = pd.merge(Output_SAT, attendance, how='inner', on='District')
print attend.columns
# Out:
# Index([u'Num of SAT Test Takers', u'SAT Critical Reading Avg. Score',
#        u'SAT Math Avg. Score', u'SAT Writing Avg. Score', u'SAT Total TOTAL',
#        u'Unnamed: 8', u'Unnamed: 9', u'Unnamed: 10', u'Unnamed: 11',
#        u'District', u'Dist', u'YTD % Attendance (Avg)',
#        u'YTD Enrollment (Avg)'],
#       dtype='object')

# %%
Output_SAT.columns
# Out:
# Index([u'Num of SAT Test Takers', u'SAT Critical Reading Avg. Score',
#        u'SAT Math Avg. Score', u'SAT Writing Avg. Score', u'SAT Total TOTAL',
#        u'Unnamed: 8', u'Unnamed: 9', u'Unnamed: 10', u'Unnamed: 11',
#        u'District'],
#       dtype='object')

# %%
Output_SAT['District'] = Output_SAT.index.get_values()

# %%
Output_SAT.columns
# Out:
# Index([u'Num of SAT Test Takers', u'SAT Critical Reading Avg. Score',
#        u'SAT Math Avg. Score', u'SAT Writing Avg. Score', u'SAT Total TOTAL',
#        u'Unnamed: 8', u'Unnamed: 9', u'Unnamed: 10', u'Unnamed: 11',
#        u'District'],
#       dtype='object')

# %%
attend = pd.merge(Output_SAT, attendance, how='inner', on='District')
print attend.columns
# Out:
# Index([u'Num of SAT Test Takers', u'SAT Critical Reading Avg. Score',
#        u'SAT Math Avg. Score', u'SAT Writing Avg. Score', u'SAT Total TOTAL',
#        u'Unnamed: 8', u'Unnamed: 9', u'Unnamed: 10', u'Unnamed: 11',
#        u'District', u'Dist', u'YTD % Attendance (Avg)',
#        u'YTD Enrollment (Avg)'],
#       dtype='object')

# %%
attend_2 = attend[0:32] 
X_2 = attend['YTD % Attendance (Avg)'][0:32]
Y_2 = attend['SAT Total TOTAL'][0:32]
X_2.index = Y_2.index
X_2
# Out:
# 0     91.18
# 1     89.01
# 2     89.20
# 3     91.13
# 4     89.08
# 5     91.34
# 6     86.75
# 7     87.15
# 8     89.27
# 9     88.92
# 10    89.84
# 11    87.33
# 12    89.56
# 13    89.41
# 14    91.27
# 15    85.55
# 16    89.67
# 17    89.83
# 18    87.81
# 19    92.77
# 20    90.50
# 21    92.57
# 22    86.98
# 23    92.21
# 24    91.90
# 25    93.34
# 26    89.88
# 27    91.70
# 28    92.14
# 29    92.79
# 30    90.98
# 31    89.28
# Name: YTD % Attendance (Avg), dtype: float64

# %%
model4 = smf.ols(formula='(Y_2) ~ I(X_2) + I(X_2**2)' , data= attend_2)
fit4 = model4.fit()
fit4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Y_2   R-squared:                       0.529
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     16.31
# Date:                Fri, 11 Dec 2015   Prob (F-statistic):           1.80e-05
# Time:                        02:04:06   Log-Likelihood:                -176.98
# No. Observations:                  32   AIC:                             360.0
# Df Residuals:                      29   BIC:                             364.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept    1.603e+04   2.12e+04      0.757      0.455     -2.73e+04  5.93e+04
# I(X_2)       -363.6861    472.337     -0.770      0.448     -1329.723   602.351
# I(X_2 ** 2)     2.2103      2.632      0.840      0.408        -3.174     7.594
# ==============================================================================
# Omnibus:                        1.291   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.525   Jarque-Bera (JB):                1.074
# Skew:                           0.233   Prob(JB):                        0.585
# Kurtosis:                       2.233   Cond. No.                     1.52e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.52e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
b2, b1, b0 = np.polyfit(X_2, Y_2, 2)
print b0, b1, b2
# Out:
# 16028.3073198 -363.686102008 2.21025337383

# %%
#Plotting the second degree linear regression line
x_dummy = np.arange(84,95,.5)
y_predicted = b2*x_dummy**2 + b1*x_dummy + b0

pl.figure(figsize=(5, 5))
pl.scatter(X_2,Y_2)
pl.plot(x_dummy,y_predicted, 'k')
pl.xlabel('UnitsTotal')
pl.ylabel('Building Energy Consumption')

# %%
class_size = pd.read_csv('2010-2011_Class_Size_-_School-level_detail.csv')

# %%
class_size['District'] = class_size['CSD']
classsize = class_size.groupby(['District','GRADE','CORE SUBJECT']).mean()

# %%
classsize.head()
# Out:
#                               CSD  NUMBER OF STUDENTS / SEATS FILLED  \
# District GRADE  CORE SUBJECT
# 1        0K     -               1                          36.259259
#          0K-09  -               1                          13.968750
#          1      -               1                          31.964286
#          12-Sep ENGLISH         1                          75.788462
#                 MATH            1                          76.880952
#
#                               NUMBER OF SECTIONS  AVERAGE CLASS SIZE  \
# District GRADE  CORE SUBJECT
# 1        0K     -                       1.777778           20.066667
#          0K-09  -                       1.562500            8.962500
#          1      -                       1.607143           19.696429
#          12-Sep ENGLISH                 3.480769           21.226923
#                 MATH                    3.309524           22.433333
#
#                               SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS  \
# District GRADE  CORE SUBJECT
# 1        0K     -                           19.37037              20.777778
#          0K-09  -                            8.37500               9.531250
#          1      -                           19.00000              20.428571
#          12-Sep ENGLISH                     18.00000              24.519231
#                 MATH                        19.00000              25.404762
#
#                               SCHOOLWIDE PUPIL-TEACHER RATIO
# District GRADE  CORE SUBJECT
# 1        0K     -                                        NaN
#          0K-09  -                                        NaN
#          1      -                                        NaN
#          12-Sep ENGLISH                                  NaN
#                 MATH                                     NaN

# %%
classsize_2 = classsize[ (classsize.index.get_level_values('GRADE') == 'MS Core') & 
              (classsize.index.get_level_values('CORE SUBJECT') == 'ENGLISH') ]
classsize_2.head()
# Out:
#                                CSD  NUMBER OF STUDENTS / SEATS FILLED  \
# District GRADE   CORE SUBJECT
# 1        MS Core ENGLISH         1                          69.647059
# 2        MS Core ENGLISH         2                         156.281250
# 3        MS Core ENGLISH         3                          96.625000
# 4        MS Core ENGLISH         4                          83.875000
# 5        MS Core ENGLISH         5                         117.600000
#
#                                NUMBER OF SECTIONS  AVERAGE CLASS SIZE  \
# District GRADE   CORE SUBJECT
# 1        MS Core ENGLISH                 2.941176           21.488235
# 2        MS Core ENGLISH                 5.968750           23.375000
# 3        MS Core ENGLISH                 4.031250           22.300000
# 4        MS Core ENGLISH                 3.937500           19.793750
# 5        MS Core ENGLISH                 4.960000           22.136000
#
#                                SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS  \
# District GRADE   CORE SUBJECT
# 1        MS Core ENGLISH                    19.588235              23.176471
# 2        MS Core ENGLISH                    20.718750              25.531250
# 3        MS Core ENGLISH                    19.968750              24.375000
# 4        MS Core ENGLISH                    17.437500              22.468750
# 5        MS Core ENGLISH                    19.640000              24.360000
#
#                                SCHOOLWIDE PUPIL-TEACHER RATIO
# District GRADE   CORE SUBJECT
# 1        MS Core ENGLISH                                  NaN
# 2        MS Core ENGLISH                                  NaN
# 3        MS Core ENGLISH                                  NaN
# 4        MS Core ENGLISH                                  NaN
# 5        MS Core ENGLISH                                  NaN

# %%
check1 = classsize_2
englishScore = pd.DataFrame(Output_SAT['SAT Critical Reading Avg. Score'] + Output_SAT['SAT Writing Avg. Score'])
englishScore = englishScore[0:32]
englishScore.index = check1.index
check2 = pd.concat([check1, englishScore], axis=1)
check2 ['english_score'] = check2 [0]

# %%
print type(check2)
check2
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                CSD  NUMBER OF STUDENTS / SEATS FILLED  \
# District GRADE   CORE SUBJECT
# 1        MS Core ENGLISH         1                          69.647059
# 2        MS Core ENGLISH         2                         156.281250
# 3        MS Core ENGLISH         3                          96.625000
# 4        MS Core ENGLISH         4                          83.875000
# 5        MS Core ENGLISH         5                         117.600000
# 6        MS Core ENGLISH         6                         162.853659
# 7        MS Core ENGLISH         7                         119.218750
# 8        MS Core ENGLISH         8                         208.166667
# 9        MS Core ENGLISH         9                         151.642857
# 10       MS Core ENGLISH        10                         172.298246
# 11       MS Core ENGLISH        11                         207.833333
# 12       MS Core ENGLISH        12                         127.177778
# 13       MS Core ENGLISH        13                         101.304348
# 14       MS Core ENGLISH        14                         136.176471
# 15       MS Core ENGLISH        15                         166.935484
# 16       MS Core ENGLISH        16                         106.888889
# 17       MS Core ENGLISH        17                         168.521739
# 18       MS Core ENGLISH        18                         200.571429
# 19       MS Core ENGLISH        19                         181.392857
# 20       MS Core ENGLISH        20                         335.366667
# 21       MS Core ENGLISH        21                         306.354839
# 22       MS Core ENGLISH        22                         282.480000
# 23       MS Core ENGLISH        23                         120.516129
# 24       MS Core ENGLISH        24                         401.000000
# 25       MS Core ENGLISH        25                         199.000000
# 26       MS Core ENGLISH        26                         340.647059
# 27       MS Core ENGLISH        27                         228.666667
# 28       MS Core ENGLISH        28                         252.826087
# 29       MS Core ENGLISH        29                         253.878788
# 30       MS Core ENGLISH        30                         308.062500
# 31       MS Core ENGLISH        31                         367.527778
# 32       MS Core ENGLISH        32                         237.384615
#
#                                NUMBER OF SECTIONS  AVERAGE CLASS SIZE  \
# District GRADE   CORE SUBJECT
# 1        MS Core ENGLISH                 2.941176           21.488235
# 2        MS Core ENGLISH                 5.968750           23.375000
# 3        MS Core ENGLISH                 4.031250           22.300000
# 4        MS Core ENGLISH                 3.937500           19.793750
# 5        MS Core ENGLISH                 4.960000           22.136000
# 6        MS Core ENGLISH                 7.097561           22.024390
# 7        MS Core ENGLISH                 5.406250           19.368750
# 8        MS Core ENGLISH                 9.305556           19.488889
# 9        MS Core ENGLISH                 6.607143           20.151786
# 10       MS Core ENGLISH                 7.438596           21.040351
# 11       MS Core ENGLISH                 7.958333           23.220833
# 12       MS Core ENGLISH                 5.777778           20.688889
# 13       MS Core ENGLISH                 4.608696           20.126087
# 14       MS Core ENGLISH                 6.117647           21.200000
# 15       MS Core ENGLISH                 6.967742           19.932258
# 16       MS Core ENGLISH                 5.000000           18.766667
# 17       MS Core ENGLISH                 6.934783           20.993478
# 18       MS Core ENGLISH                 8.047619           19.623810
# 19       MS Core ENGLISH                 7.142857           21.721429
# 20       MS Core ENGLISH                13.100000           22.320000
# 21       MS Core ENGLISH                11.645161           22.612903
# 22       MS Core ENGLISH                10.720000           23.056000
# 23       MS Core ENGLISH                 5.387097           20.074194
# 24       MS Core ENGLISH                15.354839           22.022581
# 25       MS Core ENGLISH                 7.472222           22.702778
# 26       MS Core ENGLISH                12.000000           22.717647
# 27       MS Core ENGLISH                 8.843137           21.494118
# 28       MS Core ENGLISH                10.217391           23.678261
# 29       MS Core ENGLISH                 9.969697           23.315152
# 30       MS Core ENGLISH                11.750000           22.362500
# 31       MS Core ENGLISH                13.861111           22.880556
# 32       MS Core ENGLISH                 9.538462           22.115385
#
#                                SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS  \
# District GRADE   CORE SUBJECT
# 1        MS Core ENGLISH                    19.588235              23.176471
# 2        MS Core ENGLISH                    20.718750              25.531250
# 3        MS Core ENGLISH                    19.968750              24.375000
# 4        MS Core ENGLISH                    17.437500              22.468750
# 5        MS Core ENGLISH                    19.640000              24.360000
# 6        MS Core ENGLISH                    18.756098              24.951220
# 7        MS Core ENGLISH                    16.343750              21.406250
# 8        MS Core ENGLISH                    15.500000              22.611111
# 9        MS Core ENGLISH                    16.714286              22.660714
# 10       MS Core ENGLISH                    17.631579              24.087719
# 11       MS Core ENGLISH                    18.479167              27.437500
# 12       MS Core ENGLISH                    16.977778              24.533333
# 13       MS Core ENGLISH                    18.652174              22.304348
# 14       MS Core ENGLISH                    18.176471              23.823529
# 15       MS Core ENGLISH                    16.709677              22.612903
# 16       MS Core ENGLISH                    16.333333              21.000000
# 17       MS Core ENGLISH                    17.478261              23.739130
# 18       MS Core ENGLISH                    16.714286              21.666667
# 19       MS Core ENGLISH                    18.178571              24.642857
# 20       MS Core ENGLISH                    18.133333              25.400000
# 21       MS Core ENGLISH                    17.193548              27.645161
# 22       MS Core ENGLISH                    18.640000              25.800000
# 23       MS Core ENGLISH                    16.032258              24.096774
# 24       MS Core ENGLISH                    17.677419              24.774194
# 25       MS Core ENGLISH                    19.416667              25.750000
# 26       MS Core ENGLISH                    20.176471              24.823529
# 27       MS Core ENGLISH                    18.294118              24.019608
# 28       MS Core ENGLISH                    20.478261              26.304348
# 29       MS Core ENGLISH                    19.757576              27.030303
# 30       MS Core ENGLISH                    19.500000              24.406250
# 31       MS Core ENGLISH                    19.222222              25.444444
# 32       MS Core ENGLISH                    17.846154              25.692308
#
#                                SCHOOLWIDE PUPIL-TEACHER RATIO           0  \
# District GRADE   CORE SUBJECT
# 1        MS Core ENGLISH                                  NaN  837.333333
# 2        MS Core ENGLISH                                  NaN  843.517241
# 3        MS Core ENGLISH                                  NaN  841.923077
# 4        MS Core ENGLISH                                  NaN  785.857143
# 5        MS Core ENGLISH                                  NaN  808.555556
# 6        MS Core ENGLISH                                  NaN  757.700000
# 7        MS Core ENGLISH                                  NaN  750.533333
# 8        MS Core ENGLISH                                  NaN  759.066667
# 9        MS Core ENGLISH                                  NaN  745.285714
# 10       MS Core ENGLISH                                  NaN  786.192308
# 11       MS Core ENGLISH                                  NaN  766.117647
# 12       MS Core ENGLISH                                  NaN  717.600000
# 13       MS Core ENGLISH                                  NaN  814.500000
# 14       MS Core ENGLISH                                  NaN  778.714286
# 15       MS Core ENGLISH                                  NaN  773.909091
# 16       MS Core ENGLISH                                  NaN  720.250000
# 17       MS Core ENGLISH                                  NaN  758.500000
# 18       MS Core ENGLISH                                  NaN  749.071429
# 19       MS Core ENGLISH                                  NaN  726.250000
# 20       MS Core ENGLISH                                  NaN  778.000000
# 21       MS Core ENGLISH                                  NaN  782.727273
# 22       MS Core ENGLISH                                  NaN  908.800000
# 23       MS Core ENGLISH                                  NaN  710.000000
# 24       MS Core ENGLISH                                  NaN  808.000000
# 25       MS Core ENGLISH                                  NaN  841.090909
# 26       MS Core ENGLISH                                  NaN  890.000000
# 27       MS Core ENGLISH                                  NaN  796.272727
# 28       MS Core ENGLISH                                  NaN  873.545455
# 29       MS Core ENGLISH                                  NaN  772.888889
# 30       MS Core ENGLISH                                  NaN  867.500000
# 31       MS Core ENGLISH                                  NaN  896.250000
# 32       MS Core ENGLISH                                  NaN  731.285714
#
#                                english_score
# District GRADE   CORE SUBJECT
# 1        MS Core ENGLISH          837.333333
# 2        MS Core ENGLISH          843.517241
# 3        MS Core ENGLISH          841.923077
# 4        MS Core ENGLISH          785.857143
# 5        MS Core ENGLISH          808.555556
# 6        MS Core ENGLISH          757.700000
# 7        MS Core ENGLISH          750.533333
# 8        MS Core ENGLISH          759.066667
# 9        MS Core ENGLISH          745.285714
# 10       MS Core ENGLISH          786.192308
# 11       MS Core ENGLISH          766.117647
# 12       MS Core ENGLISH          717.600000
# 13       MS Core ENGLISH          814.500000
# 14       MS Core ENGLISH          778.714286
# 15       MS Core ENGLISH          773.909091
# 16       MS Core ENGLISH          720.250000
# 17       MS Core ENGLISH          758.500000
# 18       MS Core ENGLISH          749.071429
# 19       MS Core ENGLISH          726.250000
# 20       MS Core ENGLISH          778.000000
# 21       MS Core ENGLISH          782.727273
# 22       MS Core ENGLISH          908.800000
# 23       MS Core ENGLISH          710.000000
# 24       MS Core ENGLISH          808.000000
# 25       MS Core ENGLISH          841.090909
# 26       MS Core ENGLISH          890.000000
# 27       MS Core ENGLISH          796.272727
# 28       MS Core ENGLISH          873.545455
# 29       MS Core ENGLISH          772.888889
# 30       MS Core ENGLISH          867.500000
# 31       MS Core ENGLISH          896.250000
# 32       MS Core ENGLISH          731.285714

# %%
check2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 32 entries, (1, MS Core, ENGLISH) to (32, MS Core, ENGLISH)
# Data columns (total 9 columns):
# CSD                                  32 non-null int64
# NUMBER OF STUDENTS / SEATS FILLED    32 non-null float64
# NUMBER OF SECTIONS                   32 non-null float64
# AVERAGE CLASS SIZE                   32 non-null float64
# SIZE OF SMALLEST CLASS               32 non-null float64
# SIZE OF LARGEST CLASS                32 non-null float64
# SCHOOLWIDE PUPIL-TEACHER RATIO       0 non-null float64
# 0                                    32 non-null float64
# english_score                        32 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 2.9+ KB

# %%
check2['ave_size'] = check2['AVERAGE CLASS SIZE']

# %%
import statsmodels.formula.api as smf
model_class_size = smf.ols(formula = 'english_score ~ ave_size', data=check2)
fit_class = model_class_size.fit()
print fit_class.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          english_score   R-squared:                       0.376
# Model:                            OLS   Adj. R-squared:                  0.356
# Method:                 Least Squares   F-statistic:                     18.11
# Date:                Fri, 11 Dec 2015   Prob (F-statistic):           0.000189
# Time:                        02:21:53   Log-Likelihood:                -165.54
# No. Observations:                  32   AIC:                             335.1
# Df Residuals:                      30   BIC:                             338.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    264.2508    124.518      2.122      0.042         9.951   518.550
# ave_size      24.5665      5.774      4.255      0.000        12.775    36.358
# ==============================================================================
# Omnibus:                        1.371   Durbin-Watson:                   2.126
# Prob(Omnibus):                  0.504   Jarque-Bera (JB):                0.980
# Skew:                          -0.088   Prob(JB):                        0.613
# Kurtosis:                       2.161   Cond. No.                         345.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pl.figure(figsize=(5, 5))
pl.scatter(ave_size, english_score)
plot(ave_size, fit_class.predict(), 'k')
pl.ylabel('Average SAT Score')
pl.xlabel('Average School Attendance')

# %%
model_class_size_2 = smf.ols(formula='(english_score) ~ I(ave_size) + I(ave_size**2)' , data=check2)
fit_class_size = model_class_size_2.fit()
fit_class_size.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          english_score   R-squared:                       0.388
# Model:                            OLS   Adj. R-squared:                  0.346
# Method:                 Least Squares   F-statistic:                     9.190
# Date:                Fri, 11 Dec 2015   Prob (F-statistic):           0.000810
# Time:                        02:21:59   Log-Likelihood:                -165.24
# No. Observations:                  32   AIC:                             336.5
# Df Residuals:                      29   BIC:                             340.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept         1847.7975   2142.850      0.862      0.396     -2534.823  6230.418
# I(ave_size)       -124.6586    201.668     -0.618      0.541      -537.117   287.800
# I(ave_size ** 2)     3.5011      4.730      0.740      0.465        -6.172    13.174
# ==============================================================================
# Omnibus:                        1.269   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.530   Jarque-Bera (JB):                0.944
# Skew:                          -0.087   Prob(JB):                        0.624
# Kurtosis:                       2.177   Cond. No.                     1.29e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
b2_class, b1_class, b0_class = np.polyfit(ave_size, english_score, 2)
print b2_class, b1_class, b0_class
#Plotting the second degree linear regression line
x_dummy_class = np.arange(18,24,.5)
y_predicted_class = b2_class*x_dummy_class**2 + b1_class*x_dummy_class + b0_class

pl.figure(figsize=(5, 5))
pl.scatter(ave_size, english_score)
pl.plot(x_dummy_class,y_predicted_class, 'k')
pl.xlabel('Average English Class Size')
pl.ylabel('SAT Writing + Reading Score')
# Out:
# 3.50108470033 -124.658626278 1847.79753555

# %%
classsize_math = classsize[ (classsize.index.get_level_values('GRADE') == 'MS Core') & 
              (classsize.index.get_level_values('CORE SUBJECT') == 'MATH') ]
classsize_math.head()
# Out:
#                                CSD  NUMBER OF STUDENTS / SEATS FILLED  \
# District GRADE   CORE SUBJECT
# 1        MS Core MATH            1                          60.840000
# 2        MS Core MATH            2                         154.361111
# 3        MS Core MATH            3                          83.400000
# 4        MS Core MATH            4                          66.619048
# 5        MS Core MATH            5                          95.142857
#
#                                NUMBER OF SECTIONS  AVERAGE CLASS SIZE  \
# District GRADE   CORE SUBJECT
# 1        MS Core MATH                    2.760000           21.888000
# 2        MS Core MATH                    5.888889           24.427778
# 3        MS Core MATH                    3.425000           22.815000
# 4        MS Core MATH                    3.047619           20.804762
# 5        MS Core MATH                    4.357143           21.103571
#
#                                SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS  \
# District GRADE   CORE SUBJECT
# 1        MS Core MATH                       19.800000              23.480000
# 2        MS Core MATH                       21.527778              26.833333
# 3        MS Core MATH                       20.275000              25.100000
# 4        MS Core MATH                       19.190476              22.357143
# 5        MS Core MATH                       18.857143              23.428571
#
#                                SCHOOLWIDE PUPIL-TEACHER RATIO
# District GRADE   CORE SUBJECT
# 1        MS Core MATH                                     NaN
# 2        MS Core MATH                                     NaN
# 3        MS Core MATH                                     NaN
# 4        MS Core MATH                                     NaN
# 5        MS Core MATH                                     NaN

# %%
check3 = classsize_math
mathScore = pd.DataFrame(Output_SAT['SAT Math Avg. Score'])
mathScore = mathScore[0:32]
mathScore.index = check3.index
check4 = pd.concat([check3, mathScore], axis=1)
check4
# Out:
#                                CSD  NUMBER OF STUDENTS / SEATS FILLED  \
# District GRADE   CORE SUBJECT
# 1        MS Core MATH            1                          60.840000
# 2        MS Core MATH            2                         154.361111
# 3        MS Core MATH            3                          83.400000
# 4        MS Core MATH            4                          66.619048
# 5        MS Core MATH            5                          95.142857
# 6        MS Core MATH            6                         144.354167
# 7        MS Core MATH            7                         104.868421
# 8        MS Core MATH            8                         137.319149
# 9        MS Core MATH            9                         134.014925
# 10       MS Core MATH           10                         137.214286
# 11       MS Core MATH           11                         164.381818
# 12       MS Core MATH           12                          89.295082
# 13       MS Core MATH           13                          82.875000
# 14       MS Core MATH           14                         127.473684
# 15       MS Core MATH           15                         125.500000
# 16       MS Core MATH           16                          76.222222
# 17       MS Core MATH           17                         106.125000
# 18       MS Core MATH           18                         157.148148
# 19       MS Core MATH           19                         144.181818
# 20       MS Core MATH           20                         262.243243
# 21       MS Core MATH           21                         188.046512
# 22       MS Core MATH           22                         205.911765
# 23       MS Core MATH           23                          98.058824
# 24       MS Core MATH           24                         257.121951
# 25       MS Core MATH           25                         158.911111
# 26       MS Core MATH           26                         222.782609
# 27       MS Core MATH           27                         164.530303
# 28       MS Core MATH           28                         188.586207
# 29       MS Core MATH           29                         183.146341
# 30       MS Core MATH           30                         234.375000
# 31       MS Core MATH           31                         268.391304
# 32       MS Core MATH           32                         234.928571
#
#                                NUMBER OF SECTIONS  AVERAGE CLASS SIZE  \
# District GRADE   CORE SUBJECT
# 1        MS Core MATH                    2.760000           21.888000
# 2        MS Core MATH                    5.888889           24.427778
# 3        MS Core MATH                    3.425000           22.815000
# 4        MS Core MATH                    3.047619           20.804762
# 5        MS Core MATH                    4.357143           21.103571
# 6        MS Core MATH                    5.979167           23.133333
# 7        MS Core MATH                    4.710526           20.131579
# 8        MS Core MATH                    6.085106           20.727660
# 9        MS Core MATH                    5.776119           20.728358
# 10       MS Core MATH                    5.628571           22.212857
# 11       MS Core MATH                    6.163636           24.152727
# 12       MS Core MATH                    3.868852           21.937705
# 13       MS Core MATH                    3.791667           21.412500
# 14       MS Core MATH                    5.421053           22.636842
# 15       MS Core MATH                    5.236842           21.023684
# 16       MS Core MATH                    3.555556           20.944444
# 17       MS Core MATH                    4.446429           21.567857
# 18       MS Core MATH                    6.222222           21.451852
# 19       MS Core MATH                    5.696970           22.396970
# 20       MS Core MATH                   10.027027           23.227027
# 21       MS Core MATH                    7.000000           24.623256
# 22       MS Core MATH                    7.617647           24.541176
# 23       MS Core MATH                    4.500000           19.870588
# 24       MS Core MATH                    9.926829           22.721951
# 25       MS Core MATH                    5.933333           24.706667
# 26       MS Core MATH                    7.826087           24.252174
# 27       MS Core MATH                    6.303030           22.209091
# 28       MS Core MATH                    7.310345           24.989655
# 29       MS Core MATH                    7.170732           24.143902
# 30       MS Core MATH                    9.218750           23.443750
# 31       MS Core MATH                    9.956522           24.486957
# 32       MS Core MATH                    9.642857           21.692857
#
#                                SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS  \
# District GRADE   CORE SUBJECT
# 1        MS Core MATH                       19.800000              23.480000
# 2        MS Core MATH                       21.527778              26.833333
# 3        MS Core MATH                       20.275000              25.100000
# 4        MS Core MATH                       19.190476              22.357143
# 5        MS Core MATH                       18.857143              23.428571
# 6        MS Core MATH                       20.020833              25.750000
# 7        MS Core MATH                       17.578947              22.157895
# 8        MS Core MATH                       17.340426              23.468085
# 9        MS Core MATH                       17.895522              22.970149
# 10       MS Core MATH                       19.442857              24.400000
# 11       MS Core MATH                       20.690909              27.163636
# 12       MS Core MATH                       19.311475              24.426230
# 13       MS Core MATH                       20.125000              22.958333
# 14       MS Core MATH                       20.263158              24.789474
# 15       MS Core MATH                       17.605263              23.578947
# 16       MS Core MATH                       19.111111              22.666667
# 17       MS Core MATH                       18.500000              23.946429
# 18       MS Core MATH                       18.296296              23.703704
# 19       MS Core MATH                       19.939394              24.212121
# 20       MS Core MATH                       19.378378              25.783784
# 21       MS Core MATH                       21.116279              27.604651
# 22       MS Core MATH                       21.617647              26.411765
# 23       MS Core MATH                       16.441176              23.029412
# 24       MS Core MATH                       19.414634              24.926829
# 25       MS Core MATH                       22.244444              26.666667
# 26       MS Core MATH                       22.347826              25.739130
# 27       MS Core MATH                       19.712121              24.242424
# 28       MS Core MATH                       22.034483              27.344828
# 29       MS Core MATH                       21.414634              26.560976
# 30       MS Core MATH                       20.468750              25.468750
# 31       MS Core MATH                       21.586957              26.478261
# 32       MS Core MATH                       17.571429              24.428571
#
#                                SCHOOLWIDE PUPIL-TEACHER RATIO  \
# District GRADE   CORE SUBJECT
# 1        MS Core MATH                                     NaN
# 2        MS Core MATH                                     NaN
# 3        MS Core MATH                                     NaN
# 4        MS Core MATH                                     NaN
# 5        MS Core MATH                                     NaN
# 6        MS Core MATH                                     NaN
# 7        MS Core MATH                                     NaN
# 8        MS Core MATH                                     NaN
# 9        MS Core MATH                                     NaN
# 10       MS Core MATH                                     NaN
# 11       MS Core MATH                                     NaN
# 12       MS Core MATH                                     NaN
# 13       MS Core MATH                                     NaN
# 14       MS Core MATH                                     NaN
# 15       MS Core MATH                                     NaN
# 16       MS Core MATH                                     NaN
# 17       MS Core MATH                                     NaN
# 18       MS Core MATH                                     NaN
# 19       MS Core MATH                                     NaN
# 20       MS Core MATH                                     NaN
# 21       MS Core MATH                                     NaN
# 22       MS Core MATH                                     NaN
# 23       MS Core MATH                                     NaN
# 24       MS Core MATH                                     NaN
# 25       MS Core MATH                                     NaN
# 26       MS Core MATH                                     NaN
# 27       MS Core MATH                                     NaN
# 28       MS Core MATH                                     NaN
# 29       MS Core MATH                                     NaN
# 30       MS Core MATH                                     NaN
# 31       MS Core MATH                                     NaN
# 32       MS Core MATH                                     NaN
#
#                                SAT Math Avg. Score
# District GRADE   CORE SUBJECT
# 1        MS Core MATH                   468.444444
# 2        MS Core MATH                   441.344828
# 3        MS Core MATH                   426.000000
# 4        MS Core MATH                   405.285714
# 5        MS Core MATH                   409.666667
# 6        MS Core MATH                   394.300000
# 7        MS Core MATH                   381.733333
# 8        MS Core MATH                   381.466667
# 9        MS Core MATH                   379.571429
# 10       MS Core MATH                   409.692308
# 11       MS Core MATH                   391.823529
# 12       MS Core MATH                   370.066667
# 13       MS Core MATH                   414.500000
# 14       MS Core MATH                   393.714286
# 15       MS Core MATH                   394.909091
# 16       MS Core MATH                   367.250000
# 17       MS Core MATH                   388.388889
# 18       MS Core MATH                   374.214286
# 19       MS Core MATH                   377.583333
# 20       MS Core MATH                   477.200000
# 21       MS Core MATH                   417.181818
# 22       MS Core MATH                   480.600000
# 23       MS Core MATH                   375.166667
# 24       MS Core MATH                   434.000000
# 25       MS Core MATH                   458.545455
# 26       MS Core MATH                   487.600000
# 27       MS Core MATH                   419.818182
# 28       MS Core MATH                   463.181818
# 29       MS Core MATH                   396.333333
# 30       MS Core MATH                   471.750000
# 31       MS Core MATH                   462.916667
# 32       MS Core MATH                   376.000000

# %%
check4['avg_size_math'] = check4['AVERAGE CLASS SIZE']

# %%
math_score = check4['SAT Math Avg. Score']

# %%
model_class_size_math = smf.ols(formula = 'math_score ~ avg_size_math', data=check4)
fit_class_math = model_class_size_math.fit()
print fit_class_math.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             math_score   R-squared:                       0.444
# Model:                            OLS   Adj. R-squared:                  0.425
# Method:                 Least Squares   F-statistic:                     23.95
# Date:                Fri, 11 Dec 2015   Prob (F-statistic):           3.15e-05
# Time:                        02:22:15   Log-Likelihood:                -151.72
# No. Observations:                  32   AIC:                             307.4
# Df Residuals:                      30   BIC:                             310.4
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Intercept        40.4360     76.775      0.527      0.602      -116.360   197.232
# avg_size_math    16.6521      3.403      4.894      0.000         9.702    23.602
# ==============================================================================
# Omnibus:                        0.374   Durbin-Watson:                   2.150
# Prob(Omnibus):                  0.829   Jarque-Bera (JB):                0.507
# Skew:                           0.212   Prob(JB):                        0.776
# Kurtosis:                       2.552   Cond. No.                         343.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
ave_size_math.index = math_score.index
pl.figure(figsize=(5, 5))
pl.scatter(ave_size_math , math_score)
plot(ave_size_math, fit_class_math.predict(), 'k')
pl.ylabel('Average SAT Score')
pl.xlabel('Average School Attendance')

# %%
model_class_size_math = smf.ols(formula='(math_score) ~ I(ave_size_math) + I(ave_size_math**2)' , data=check4)
fit_class_size_math = model_class_size_math.fit()
fit_class_size_math.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             math_score   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     11.61
# Date:                Fri, 11 Dec 2015   Prob (F-statistic):           0.000198
# Time:                        02:22:21   Log-Likelihood:                -151.69
# No. Observations:                  32   AIC:                             309.4
# Df Residuals:                      29   BIC:                             313.8
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------
# Intercept               316.0864   1344.235      0.235      0.816     -2433.183  3065.355
# I(ave_size_math)         -7.8584    119.377     -0.066      0.948      -252.011   236.294
# I(ave_size_math ** 2)     0.5425      2.641      0.205      0.839        -4.859     5.944
# ==============================================================================
# Omnibus:                        0.470   Durbin-Watson:                   2.170
# Prob(Omnibus):                  0.790   Jarque-Bera (JB):                0.537
# Skew:                           0.255   Prob(JB):                        0.764
# Kurtosis:                       2.621   Cond. No.                     1.35e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
b2_class_math, b1_class_math, b0_class_math = np.polyfit(ave_size_math, math_score, 2)
print b2_class_math, b1_class_math, b0_class_math
#Plotting the second degree linear regression line
x_dummy_class_math = np.arange(19,26,.5)
y_predicted_class_math = b2_class_math*x_dummy_class_math**2 + b1_class_math*x_dummy_class_math + b0_class_math

pl.figure(figsize=(5, 5))
pl.scatter(ave_size_math, math_score)
pl.plot(x_dummy_class_math, y_predicted_class_math, 'k')
pl.xlabel('Average Math Class Size')
pl.ylabel('SAT MATH Score')
# Out:
# 0.542495020678 -7.85842916493 316.086365737

# %%
english_test_score = pd.read_csv('English_Language_Arts__ELA__Test_Results_2006-2012_-_District_-_All_Students.csv')
english_test_score.info()english_test_score
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1568 entries, 0 to 1567
# Data columns (total 16 columns):
# District             1568 non-null int64
# Grade                1568 non-null object
# Year                 1568 non-null int64
# Demographic          1568 non-null object
# Number Tested        1568 non-null int64
# Mean Scale Score     1568 non-null int64
# Num Level 1          1568 non-null int64
# Pct Level 1          1568 non-null float64
# Num Level 2          1568 non-null int64
# Pct Level 2          1568 non-null float64
# Num Level 3          1568 non-null int64
# Pct Level 3          1568 non-null float64
# Num Level 4          1568 non-null int64
# Pct Level 4          1568 non-null float64
# Num Level 3 and 4    1568 non-null int64
# Pct Level 3 and 4    1568 non-null float64
# dtypes: float64(5), int64(9), object(2)
# memory usage: 208.2+ KB

# %%
english_2006_score = english_test_score.groupby(['District' , 'Grade' , 'Year']).mean()
# Out:
#                           Number Tested  Mean Scale Score  Num Level 1  \
# District Grade      Year
# 1        3          2006            808               663           89
#                     2007            826               659           94
#                     2008            852               662           60
#                     2009            901               667           45
#                     2010            848               669          137
#                     2011            813               665          103
#                     2012            856               663          123
#          4          2006            819               654          103
#                     2007            860               655           70
#                     2008            843               657           74
#                     2009            841               664           41
#                     2010            892               669           90
#                     2011            853               672           81
#                     2012            812               674           74
#          5          2006            751               651           68
#                     2007            854               657           61
#                     2008            849               663           21
#                     2009            802               674            2
#                     2010            793               672          124
#                     2011            858               668           85
#                     2012            833               669           95
#          6          2006            855               653           58
#                     2007            785               654           20
#                     2008            867               655           23
#                     2009            881               667            1
#                     2010            784               664          108
#                     2011            814               662          108
#                     2012            897               663          112
#          7          2006            919               646           85
#                     2007            899               650           57
# ...                                 ...               ...          ...
# 32       5          2011           1292               664          178
#                     2012           1296               664          185
#          6          2006           1494               640          210
#                     2007           1540               643           95
#                     2008           1617               648           63
#                     2009           1572               659            3
#                     2010           1333               654          320
#                     2011           1377               654          357
#                     2012           1321               656          243
#          7          2006           1445               630          271
#                     2007           1615               638          207
#                     2008           1529               650           41
#                     2009           1565               656            9
#                     2010           1501               657          269
#                     2011           1323               654          278
#                     2012           1335               656          231
#          8          2006           1584               632          315
#                     2007           1507               631          268
#                     2008           1500               644          138
#                     2009           1530               649           62
#                     2010           1553               645          316
#                     2011           1513               645          227
#                     2012           1259               648          169
#          All Grades 2006           8438               639         1331
#                     2007           9179               641         1203
#                     2008           8897               648          643
#                     2009           8652               656          285
#                     2010           8304               656         1635
#                     2011           8046               655         1452
#                     2012           7688               657         1225
#
#                           Pct Level 1  Num Level 2  Pct Level 2  Num Level 3  \
# District Grade      Year
# 1        3          2006         11.0          215         26.6          462
#                     2007         11.4          242         29.3          427
#                     2008          7.0          270         31.7          449
#                     2009          5.0          221         24.5          553
#                     2010         16.2          276         32.5          272
#                     2011         12.7          265         32.6          371
#                     2012         14.4          294         34.3          379
#          4          2006         12.6          272         33.2          405
#                     2007          8.1          286         33.3          469
#                     2008          8.8          251         29.8          480
#                     2009          4.9          216         25.7          533
#                     2010         10.1          386         43.3          372
#                     2011          9.5          313         36.7          420
#                     2012          9.1          296         36.5          392
#          5          2006          9.1          286         38.1          342
#                     2007          7.1          293         34.3          461
#                     2008          2.5          210         24.7          571
#                     2009          0.2          144         18.0          556
#                     2010         15.6          308         38.8          252
#                     2011          9.9          322         37.5          393
#                     2012         11.4          277         33.3          406
#          6          2006          6.8          346         40.5          363
#                     2007          2.5          365         46.5          344
#                     2008          2.7          382         44.1          426
#                     2009          0.1          223         25.3          562
#                     2010         13.8          334         42.6          269
#                     2011         13.3          309         38.0          340
#                     2012         12.5          329         36.7          414
#          7          2006          9.2          425         46.2          341
#                     2007          6.3          390         43.4          418
# ...                               ...          ...          ...          ...
# 32       5          2011         13.8          568         44.0          500
#                     2012         14.3          533         41.1          547
#          6          2006         14.1          647         43.3          557
#                     2007          6.2          854         55.5          551
#                     2008          3.9          784         48.5          745
#                     2009          0.2          463         29.5         1042
#                     2010         24.0          554         41.6          433
#                     2011         25.9          557         40.5          444
#                     2012         18.4          598         45.3          467
#          7          2006         18.8          687         47.5          462
#                     2007         12.8          757         46.9          606
#                     2008          2.7          699         45.7          772
#                     2009          0.6          562         35.9          970
#                     2010         17.9          749         49.9          415
#                     2011         21.0          669         50.6          360
#                     2012         17.3          684         51.2          403
#          8          2006         19.9          766         48.4          484
#                     2007         17.8          805         53.4          412
#                     2008          9.2          781         52.1          528
#                     2009          4.1          667         43.6          775
#                     2010         20.3          790         50.9          417
#                     2011         15.0          891         58.9          390
#                     2012         13.4          704         55.9          386
#          All Grades 2006         15.8         3650         43.3         3250
#                     2007         13.1         4302         46.9         3492
#                     2008          7.2         3848         43.3         4204
#                     2009          3.3         2963         34.2         5110
#                     2010         19.7         3842         46.3         2487
#                     2011         18.0         3827         47.6         2671
#                     2012         15.9         3601         46.8         2766
#
#                           Pct Level 3  Num Level 4  Pct Level 4  \
# District Grade      Year
# 1        3          2006         57.2           42          5.2
#                     2007         51.7           63          7.6
#                     2008         52.7           73          8.6
#                     2009         61.4           82          9.1
#                     2010         32.1          163         19.2
#                     2011         45.6           74          9.1
#                     2012         44.3           60          7.0
#          4          2006         49.5           39          4.8
#                     2007         54.5           35          4.1
#                     2008         56.9           38          4.5
#                     2009         63.4           51          6.1
#                     2010         41.7           44          4.9
#                     2011         49.2           39          4.6
#                     2012         48.3           50          6.2
#          5          2006         45.5           55          7.3
#                     2007         54.0           39          4.6
#                     2008         67.3           47          5.5
#                     2009         69.3          100         12.5
#                     2010         31.8          109         13.7
#                     2011         45.8           58          6.8
#                     2012         48.7           55          6.6
#          6          2006         42.5           88         10.3
#                     2007         43.8           56          7.1
#                     2008         49.1           36          4.2
#                     2009         63.8           95         10.8
#                     2010         34.3           73          9.3
#                     2011         41.8           57          7.0
#                     2012         46.2           42          4.7
#          7          2006         37.1           68          7.4
#                     2007         46.5           34          3.8
# ...                               ...          ...          ...
# 32       5          2011         38.7           46          3.6
#                     2012         42.2           31          2.4
#          6          2006         37.3           80          5.4
#                     2007         35.8           40          2.6
#                     2008         46.1           25          1.5
#                     2009         66.3           64          4.1
#                     2010         32.5           26          2.0
#                     2011         32.2           19          1.4
#                     2012         35.4           13          1.0
#          7          2006         32.0           25          1.7
#                     2007         37.5           45          2.8
#                     2008         50.5           17          1.1
#                     2009         62.0           24          1.5
#                     2010         27.6           68          4.5
#                     2011         27.2           16          1.2
#                     2012         30.2           17          1.3
#          8          2006         30.6           19          1.2
#                     2007         27.3           22          1.5
#                     2008         35.2           53          3.5
#                     2009         50.7           26          1.7
#                     2010         26.9           30          1.9
#                     2011         25.8            5          0.3
#                     2012         30.7            0          0.0
#          All Grades 2006         38.5          207          2.5
#                     2007         38.0          182          2.0
#                     2008         47.3          202          2.3
#                     2009         59.1          294          3.4
#                     2010         29.9          340          4.1
#                     2011         33.2           96          1.2
#                     2012         36.0           96          1.2
#
#                           Num Level 3 and 4  Pct Level 3 and 4
# District Grade      Year
# 1        3          2006                504               62.4
#                     2007                490               59.3
#                     2008                522               61.3
#                     2009                635               70.5
#                     2010                435               51.3
#                     2011                445               54.7
#                     2012                439               51.3
#          4          2006                444               54.2
#                     2007                504               58.6
#                     2008                518               61.4
#                     2009                584               69.4
#                     2010                416               46.6
#                     2011                459               53.8
#                     2012                442               54.4
#          5          2006                397               52.9
#                     2007                500               58.5
#                     2008                618               72.8
#                     2009                656               81.8
#                     2010                361               45.5
#                     2011                451               52.6
#                     2012                461               55.3
#          6          2006                451               52.7
#                     2007                400               51.0
#                     2008                462               53.3
#                     2009                657               74.6
#                     2010                342               43.6
#                     2011                397               48.8
#                     2012                456               50.8
#          7          2006                409               44.5
#                     2007                452               50.3
# ...                                     ...                ...
# 32       5          2011                546               42.3
#                     2012                578               44.6
#          6          2006                637               42.6
#                     2007                591               38.4
#                     2008                770               47.6
#                     2009               1106               70.4
#                     2010                459               34.4
#                     2011                463               33.6
#                     2012                480               36.3
#          7          2006                487               33.7
#                     2007                651               40.3
#                     2008                789               51.6
#                     2009                994               63.5
#                     2010                483               32.2
#                     2011                376               28.4
#                     2012                420               31.5
#          8          2006                503               31.8
#                     2007                434               28.8
#                     2008                581               38.7
#                     2009                801               52.4
#                     2010                447               28.8
#                     2011                395               26.1
#                     2012                386               30.7
#          All Grades 2006               3457               41.0
#                     2007               3674               40.0
#                     2008               4406               49.5
#                     2009               5404               62.5
#                     2010               2827               34.0
#                     2011               2767               34.4
#                     2012               2862               37.2
#
# [1568 rows x 12 columns]

# %%
english_2006_score2 = english_2006_score
english_2006_score2 = english_2006_score2.reset_index()
english_2006_score2.head()
# Out:
#    District Grade  Year  Number Tested  Mean Scale Score  Num Level 1  \
# 0         1     3  2006            808               663           89
# 1         1     3  2007            826               659           94
# 2         1     3  2008            852               662           60
# 3         1     3  2009            901               667           45
# 4         1     3  2010            848               669          137
#
#    Pct Level 1  Num Level 2  Pct Level 2  Num Level 3  Pct Level 3  \
# 0         11.0          215         26.6          462         57.2
# 1         11.4          242         29.3          427         51.7
# 2          7.0          270         31.7          449         52.7
# 3          5.0          221         24.5          553         61.4
# 4         16.2          276         32.5          272         32.1
#
#    Num Level 4  Pct Level 4  Num Level 3 and 4  Pct Level 3 and 4
# 0           42          5.2                504               62.4
# 1           63          7.6                490               59.3
# 2           73          8.6                522               61.3
# 3           82          9.1                635               70.5
# 4          163         19.2                435               51.3

# %%
eng_scr = english_2006_score2[(english_2006_score2.Grade == '6') & (english_2006_score2.Year== 2006)]
eng_scr = eng_scr.reset_index()
eng_scr.head()
# Out:
#    index  District Grade  Year  Number Tested  Mean Scale Score  Num Level 1  \
# 0     21         1     6  2006            855               653           58
# 1     70         2     6  2006           2106               666           76
# 2    119         3     6  2006           1473               651          124
# 3    168         4     6  2006           1409               642          124
# 4    217         5     6  2006           1224               633          159
#
#    Pct Level 1  Num Level 2  Pct Level 2  Num Level 3  Pct Level 3  \
# 0          6.8          346         40.5          363         42.5
# 1          3.6          529         25.1         1169         55.5
# 2          8.4          618         42.0          572         38.8
# 3          8.8          676         48.0          552         39.2
# 4         13.0          638         52.1          407         33.3
#
#    Num Level 4  Pct Level 4  Num Level 3 and 4  Pct Level 3 and 4
# 0           88         10.3                451               52.7
# 1          332         15.8               1501               71.3
# 2          159         10.8                731               49.6
# 3           57          4.0                609               43.2
# 4           20          1.6                427               34.9

# %%
mean_eng_scr = eng_scr['Mean Scale Score']

# %%
check6 = mean_eng_scr
englishScore = pd.DataFrame(Output_SAT['SAT Critical Reading Avg. Score'] + Output_SAT['SAT Writing Avg. Score'])
englishScore = englishScore[0:32]
englishScore.index = check6.index
check7 = pd.concat([check6, englishScore], axis=1)
# check7 ['english_score'] = check2 [0]

# %%
check7 ['eng_avg_SAT'] = check7[0]
check7
# Out:
#     Mean Scale Score           0  eng_avg_SAT
# 0                653  837.333333   837.333333
# 1                666  843.517241   843.517241
# 2                651  841.923077   841.923077
# 3                642  785.857143   785.857143
# 4                633  808.555556   808.555556
# 5                634  757.700000   757.700000
# 6                624  750.533333   750.533333
# 7                635  759.066667   759.066667
# 8                633  745.285714   745.285714
# 9                643  786.192308   786.192308
# 10               640  766.117647   766.117647
# 11               632  717.600000   717.600000
# 12               636  814.500000   814.500000
# 13               637  778.714286   778.714286
# 14               649  773.909091   773.909091
# 15               630  720.250000   720.250000
# 16               634  758.500000   758.500000
# 17               641  749.071429   749.071429
# 18               635  726.250000   726.250000
# 19               654  778.000000   778.000000
# 20               659  782.727273   782.727273
# 21               656  908.800000   908.800000
# 22               644  710.000000   710.000000
# 23               648  808.000000   808.000000
# 24               666  841.090909   841.090909
# 25               677  890.000000   890.000000
# 26               651  796.272727   796.272727
# 27               654  873.545455   873.545455
# 28               645  772.888889   772.888889
# 29               653  867.500000   867.500000
# 30               654  896.250000   896.250000
# 31               640  731.285714   731.285714
